# %%
import xarray as xr
import pandas as pd

his_ph_med = xr.open_dataset('../data/pre_processed/acid/historical/pHT_median_historical.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
his_ph_std = xr.open_dataset('../data/pre_processed/acid/historical/pHT_std_historical.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
his_ar_med = xr.open_dataset('../data/pre_processed/acid/historical/Aragonite_median_historical.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
his_ar_std = xr.open_dataset('../data/pre_processed/acid/historical/Aragonite_std_historical.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
his_cal_med = xr.open_dataset('../data/pre_processed/acid/historical/Calcite_median_historical.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
his_cal_std = xr.open_dataset('../data/pre_processed/acid/historical/Calcite_std_historical.nc').sel(lon=slice(71, 172), lat=slice(65, 119))

ssp119_ph_med = xr.open_dataset('../data/pre_processed/acid/ssp119/pHT_median_ssp119.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp119_ph_std = xr.open_dataset('../data/pre_processed/acid/ssp119/pHT_std_ssp119.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp119_ar_med = xr.open_dataset('../data/pre_processed/acid/ssp119/Aragonite_median_ssp119.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp119_ar_std = xr.open_dataset('../data/pre_processed/acid/ssp119/Aragonite_std_ssp119.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp119_cal_med = xr.open_dataset('../data/pre_processed/acid/ssp119/Calcite_median_ssp119.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp119_cal_std = xr.open_dataset('../data/pre_processed/acid/ssp119/Calcite_std_ssp119.nc').sel(lon=slice(71, 172), lat=slice(65, 119))

ssp126_ph_med = xr.open_dataset('../data/pre_processed/acid/ssp126/pHT_median_ssp126.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp126_ph_std = xr.open_dataset('../data/pre_processed/acid/ssp126/pHT_std_ssp126.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp126_ar_med = xr.open_dataset('../data/pre_processed/acid/ssp126/Aragonite_median_ssp126.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp126_ar_std = xr.open_dataset('../data/pre_processed/acid/ssp126/Aragonite_std_ssp126.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp126_cal_med = xr.open_dataset('../data/pre_processed/acid/ssp126/Calcite_median_ssp126.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp126_cal_std = xr.open_dataset('../data/pre_processed/acid/ssp126/Calcite_std_ssp126.nc').sel(lon=slice(71, 172), lat=slice(65, 119))

ssp245_ph_med = xr.open_dataset('../data/pre_processed/acid/ssp245/pHT_median_ssp245.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp245_ph_std = xr.open_dataset('../data/pre_processed/acid/ssp245/pHT_std_ssp245.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp245_ar_med = xr.open_dataset('../data/pre_processed/acid/ssp245/Aragonite_median_ssp245.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp245_ar_std = xr.open_dataset('../data/pre_processed/acid/ssp245/Aragonite_std_ssp245.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp245_cal_med = xr.open_dataset('../data/pre_processed/acid/ssp245/Calcite_median_ssp245.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp245_cal_std = xr.open_dataset('../data/pre_processed/acid/ssp245/Calcite_std_ssp245.nc').sel(lon=slice(71, 172), lat=slice(65, 119))

ssp370_ph_med = xr.open_dataset('../data/pre_processed/acid/ssp370/pHT_median_ssp370.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp370_ph_std = xr.open_dataset('../data/pre_processed/acid/ssp370/pHT_std_ssp370.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp370_ar_med = xr.open_dataset('../data/pre_processed/acid/ssp370/Aragonite_median_ssp370.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp370_ar_std = xr.open_dataset('../data/pre_processed/acid/ssp370/Aragonite_std_ssp370.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp370_cal_med = xr.open_dataset('../data/pre_processed/acid/ssp370/Calcite_median_ssp370.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp370_cal_std = xr.open_dataset('../data/pre_processed/acid/ssp370/Calcite_std_ssp370.nc').sel(lon=slice(71, 172), lat=slice(65, 119))


ssp585_ph_med = xr.open_dataset('../data/pre_processed/acid/ssp585/pHT_median_ssp585.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp585_ph_std = xr.open_dataset('../data/pre_processed/acid/ssp585/pHT_std_ssp585.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp585_ar_med = xr.open_dataset('../data/pre_processed/acid/ssp585/Aragonite_median_ssp585.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp585_ar_std = xr.open_dataset('../data/pre_processed/acid/ssp585/Aragonite_std_ssp585.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp585_cal_med = xr.open_dataset('../data/pre_processed/acid/ssp585/Calcite_median_ssp585.nc').sel(lon=slice(71, 172), lat=slice(65, 119))
ssp585_cal_std = xr.open_dataset('../data/pre_processed/acid/ssp585/Calcite_std_ssp585.nc').sel(lon=slice(71, 172), lat=slice(65, 119))

his_ph_med.to_netcdf("../data/processed/spa/his_ph_med.nc")
his_ph_std.to_netcdf("../data/processed/spa/his_ph_std.nc")
his_ar_med.to_netcdf("../data/processed/spa/his_ar_med.nc")
his_ar_std.to_netcdf("../data/processed/spa/his_ar_std.nc")
his_cal_med.to_netcdf("../data/processed/spa/his_cal_med.nc")
his_cal_std.to_netcdf("../data/processed/spa/his_cal_std.nc")

ssp119_ph_med.to_netcdf("../data/processed/spa/ssp119_ph_med.nc")
ssp119_ph_std.to_netcdf("../data/processed/spa/ssp119_std_med.nc")
ssp119_ar_med.to_netcdf("../data/processed/spa/ssp119_ar_med.nc")
ssp119_ar_std.to_netcdf("../data/processed/spa/ssp119_ar_std.nc")
ssp119_cal_med.to_netcdf("../data/processed/spa/ssp119_cal_med.nc")
ssp119_cal_std.to_netcdf("../data/processed/spa/ssp119_cal_std.nc")

ssp126_ph_med.to_netcdf("../data/processed/spa/ssp126_ph_med.nc")
ssp126_ph_std.to_netcdf("../data/processed/spa/ssp126_ph_std.nc")
ssp126_ar_med.to_netcdf("../data/processed/spa/ssp126_ar_med.nc")
ssp126_ar_std.to_netcdf("../data/processed/spa/ssp126_ar_std.nc")
ssp126_cal_med.to_netcdf("../data/processed/spa/ssp126_cal_med.nc")
ssp126_cal_std.to_netcdf("../data/processed/spa/ssp126_cal_std.nc")

ssp245_ph_med.to_netcdf("../data/processed/spa/ssp245_ph_med.nc")
ssp245_ph_std.to_netcdf("../data/processed/spa/ssp245_ph_std.nc")
ssp245_ar_med.to_netcdf("../data/processed/spa/ssp245_ar_med.nc")
ssp245_ar_std.to_netcdf("../data/processed/spa/ssp245_ar_std.nc")
ssp245_cal_med.to_netcdf("../data/processed/spa/ssp245_cal_med.nc")
ssp245_cal_std.to_netcdf("../data/processed/spa/ssp245_cal_std.nc")

ssp370_ph_med.to_netcdf("../data/processed/spa/ssp370_ph_med.nc")
ssp370_ph_std.to_netcdf("../data/processed/spa/ssp370_ph_std.nc")
ssp370_ar_med.to_netcdf("../data/processed/spa/ssp370_ar_med.nc")
ssp370_ar_std.to_netcdf("../data/processed/spa/ssp370_ar_std.nc")
ssp370_cal_med.to_netcdf("../data/processed/spa/ssp370_cal_med.nc")
ssp370_cal_std.to_netcdf("../data/processed/spa/ssp370_cal_std.nc")

ssp585_ph_med.to_netcdf("../data/processed/spa/ssp585_ph_med.nc")
ssp585_ph_std.to_netcdf("../data/processed/spa/ssp585_ph_std.nc")
ssp585_ar_med.to_netcdf("../data/processed/spa/ssp585_ar_med.nc")
ssp585_ar_std.to_netcdf("../data/processed/spa/ssp585_ar_std.nc")
ssp585_cal_med.to_netcdf("../data/processed/spa/ssp585_cal_med.nc")
ssp585_cal_std.to_netcdf("../data/processed/spa/ssp585_cal_std.nc")

tHist = his_ph_med["time"].to_numpy()
pH_med_his = his_ph_med["pHT"].mean(dim=("lat", "lon")).to_numpy()
pH_std_his = his_ph_std["pHT"].mean(dim=("lat", "lon")).to_numpy()
ar_med_his = his_ar_med["aragonite"].mean(dim=("lat", "lon")).to_numpy()
ar_std_his = his_ar_std["aragonite"].mean(dim=("lat", "lon")).to_numpy()
cal_med_his = his_cal_med["calcite"].mean(dim=("lat", "lon")).to_numpy()
cal_std_his = his_cal_std["calcite"].mean(dim=("lat", "lon")).to_numpy()

his = pd.DataFrame({"time":tHist,
             "pH_med":pH_med_his,
             "pH_std":pH_std_his,
             "aragonite_med":ar_med_his,
             "aragonite_std":ar_std_his,
             "calcite_med":cal_med_his,
             "calcite_std":cal_std_his})
his.to_csv("../data/processed/temporal/historical.csv", index=False)

tSsp119 = ssp119_ph_med["time"].to_numpy()
pH_med_ssp119 = ssp119_ph_med["pHT"].mean(dim=("lat", "lon")).to_numpy()
pH_std_ssp119 = ssp119_ph_std["pHT"].mean(dim=("lat", "lon")).to_numpy()
ar_med_ssp119 = ssp119_ar_med["aragonite"].mean(dim=("lat", "lon")).to_numpy()
ar_std_ssp119 = ssp119_ar_std["aragonite"].mean(dim=("lat", "lon")).to_numpy()
cal_med_ssp119 = ssp119_cal_med["calcite"].mean(dim=("lat", "lon")).to_numpy()
cal_std_ssp119 = ssp119_cal_std["calcite"].mean(dim=("lat", "lon")).to_numpy()

ssp119 = pd.DataFrame({"time":tSsp119,
             "pH_med":pH_med_ssp119,
             "pH_std":pH_std_ssp119,
             "aragonite_med":ar_med_ssp119,
             "aragonite_std":ar_std_ssp119,
             "calcite_med":cal_med_ssp119,
             "calcite_std":cal_std_ssp119})
ssp119.to_csv("../data/processed/temporal/ssp119.csv", index=False)

tSsp126 = ssp126_ph_med["time"].to_numpy()
pH_med_ssp126 = ssp126_ph_med["pHT"].mean(dim=("lat", "lon")).to_numpy()
pH_std_ssp126 = ssp126_ph_std["pHT"].mean(dim=("lat", "lon")).to_numpy()
ar_med_ssp126 = ssp126_ar_med["aragonite"].mean(dim=("lat", "lon")).to_numpy()
ar_std_ssp126 = ssp126_ar_std["aragonite"].mean(dim=("lat", "lon")).to_numpy()
cal_med_ssp126 = ssp126_cal_med["calcite"].mean(dim=("lat", "lon")).to_numpy()
cal_std_ssp126 = ssp126_cal_std["calcite"].mean(dim=("lat", "lon")).to_numpy()

ssp126 = pd.DataFrame({"time":tSsp126,
             "pH_med":pH_med_ssp126,
             "pH_std":pH_std_ssp126,
             "aragonite_med":ar_med_ssp126,
             "aragonite_std":ar_std_ssp126,
             "calcite_med":cal_med_ssp126,
             "calcite_std":cal_std_ssp126})
ssp126.to_csv("../data/processed/temporal/ssp126.csv", index=False)

tSsp245 = ssp245_ph_med["time"].to_numpy()
pH_med_ssp245 = ssp245_ph_med["pHT"].mean(dim=("lat", "lon")).to_numpy()
pH_std_ssp245 = ssp245_ph_std["pHT"].mean(dim=("lat", "lon")).to_numpy()
ar_med_ssp245 = ssp245_ar_med["aragonite"].mean(dim=("lat", "lon")).to_numpy()
ar_std_ssp245 = ssp245_ar_std["aragonite"].mean(dim=("lat", "lon")).to_numpy()
cal_med_ssp245 = ssp245_cal_med["calcite"].mean(dim=("lat", "lon")).to_numpy()
cal_std_ssp245 = ssp245_cal_std["calcite"].mean(dim=("lat", "lon")).to_numpy()

ssp245 = pd.DataFrame({"time":tSsp245,
             "pH_med":pH_med_ssp245,
             "pH_std":pH_std_ssp245,
             "aragonite_med":ar_med_ssp245,
             "aragonite_std":ar_std_ssp245,
             "calcite_med":cal_med_ssp245,
             "calcite_std":cal_std_ssp245})
ssp245.to_csv("../data/processed/temporal/ssp245.csv", index=False)


tSsp370 = ssp370_ph_med["time"].to_numpy()
pH_med_ssp370 = ssp370_ph_med["pHT"].mean(dim=("lat", "lon")).to_numpy()
pH_std_ssp370 = ssp370_ph_std["pHT"].mean(dim=("lat", "lon")).to_numpy()
ar_med_ssp370 = ssp370_ar_med["aragonite"].mean(dim=("lat", "lon")).to_numpy()
ar_std_ssp370 = ssp370_ar_std["aragonite"].mean(dim=("lat", "lon")).to_numpy()
cal_med_ssp370 = ssp370_cal_med["calcite"].mean(dim=("lat", "lon")).to_numpy()
cal_std_ssp370 = ssp370_cal_std["calcite"].mean(dim=("lat", "lon")).to_numpy()

ssp370 = pd.DataFrame({"time":tSsp370,
             "pH_med":pH_med_ssp370,
             "pH_std":pH_std_ssp370,
             "aragonite_med":ar_med_ssp370,
             "aragonite_std":ar_std_ssp370,
             "calcite_med":cal_med_ssp370,
             "calcite_std":cal_std_ssp370})
ssp370.to_csv("../data/processed/temporal/ssp370.csv", index=False)



tSsp585 = ssp585_ph_med["time"].to_numpy()
pH_med_ssp585 = ssp585_ph_med["pHT"].mean(dim=("lat", "lon")).to_numpy()
pH_std_ssp585 = ssp585_ph_std["pHT"].mean(dim=("lat", "lon")).to_numpy()
ar_med_ssp585 = ssp585_ar_med["aragonite"].mean(dim=("lat", "lon")).to_numpy()
ar_std_ssp585 = ssp585_ar_std["aragonite"].mean(dim=("lat", "lon")).to_numpy()
cal_med_ssp585 = ssp585_cal_med["calcite"].mean(dim=("lat", "lon")).to_numpy()
cal_std_ssp585 = ssp585_cal_std["calcite"].mean(dim=("lat", "lon")).to_numpy()

ssp585 = pd.DataFrame({"time":tSsp585,
             "pH_med":pH_med_ssp585,
             "pH_std":pH_std_ssp585,
             "aragonite_med":ar_med_ssp585,
             "aragonite_std":ar_std_ssp585,
             "calcite_med":cal_med_ssp585,
             "calcite_std":cal_std_ssp585})
ssp585.to_csv("../data/processed/temporal/ssp585.csv", index=False)

# %%
import xarray as xr

# %%
ds = xr.open_dataset('../data/processed/spa/his_ar_med.nc')

# %%
ds['aragonite'].sel(time=1750).plot()
